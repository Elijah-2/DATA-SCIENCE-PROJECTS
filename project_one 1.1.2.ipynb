# %% [markdown]
# # A.GENERAL OVERVIEW QUESTIONS ON SHOPPING TRENDS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\\ELIJAH ONYANGO\\Downloads\\shopping_trends.csv")

# %%
data
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# # 1.WHAT IS THE SIZE OF THE DATA SET?

# %% [markdown]
# ## first convert the data into a data frame

# %%
df=pd.DataFrame(data)

# %% [markdown]
# ### to check for rows and columns and rows asked we use .shape method

# %%
df.shape
# Out:
# (3900, 19)

# %% [markdown]
# ### The first value is the observations while the secon is the features

# %% [markdown]
# #### so we have 3900 observations and 19 features

# %% [markdown]
# # 2.WHAT ARE THE MAIN FEATURES OF THE DATA SET?

# %% [markdown]
# ### here we are required to calculate the number of columns in the data set, to do that we use .columns method to get the features

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %% [markdown]
# # 3.HOW TO CALCULATE THE NUMBER OF CUSTOMERS IN THE DATA SET?

# %% [raw]
# ####  a)here we are going to calculate number of unique() customers in the data set

# %%
df['Customer ID'].nunique()
# Out:
# 3900

# %% [markdown]
# #### alternatively

# %%
len(df)
# Out:
# 3900

# %% [markdown]
# # 4.CALCULATE THE TOTAL NUMBER OF TRANSACTIONS?

# %% [markdown]
# ### here we calculate the length of the data set

# %%
len(df)
# Out:
# 3900

# %% [markdown]
# # 5.AVERAGE PURCHASE AMOUNT ?

# %% [markdown]
# #### THIS IS THE TOTAL PURCHASE AMOUNT DIVIDED BY THE TOTAL TRANSACTIONS

# %%
average_purchase=df["Purchase Amount (USD)"].sum()/len(df)

# %% [markdown]
# #### alternatively we use . mean method

# %%
mean_purchase=df["Purchase Amount (USD)"].mean()

# %%
mean_purchase
# Out:
# 59.76435897435898

# %% [markdown]
# # 6.WHAT IS THE MINIMUM AND MAXIMUM PURCHASE AMOUNT ?

# %% [markdown]
# #### HERE WE ARE REQUIRED TO FIND THE MINIMUM AND MAXIMUM AMOUNT THAT IS PURCHASED BY THE CUSTOMERS WE USE .min() and .max()

# %%
min_purchase=df["Purchase Amount (USD)"].min()

# %%
min_purchase
# Out:
# 20

# %%
max_purchase=df["Purchase Amount (USD)"].max()

# %%
max_purchase
# Out:
# 100

# %% [markdown]
# #### alternativerly we can sort the  data set

# %%
sorted_min_value=df["Purchase Amount (USD)"].sort_values().head()

# %%
sorted_min_value
# Out:
# 2696    20
# 3653    20
# 3083    20
# 2652    20
# 1795    20
# Name: Purchase Amount (USD), dtype: int64

# %%
sorted_max_value=df["Purchase Amount (USD)"].sort_values().tail()
sorted_max_value
# Out:
# 243     100
# 248     100
# 3265    100
# 581     100
# 2285    100
# Name: Purchase Amount (USD), dtype: int64

# %% [markdown]
# #### the above is how we can get range of min and max purchased

# %% [markdown]
# # 7.WHAT ARE THE UNIQUE CATEGORIES OF ITEMS PURCHASED?

# %%
df['Item Purchased'].unique()
# Out:
# array(['Blouse', 'Sweater', 'Jeans', 'Sandals', 'Sneakers', 'Shirt',
#        'Shorts', 'Coat', 'Handbag', 'Shoes', 'Dress', 'Skirt',
#        'Sunglasses', 'Pants', 'Jacket', 'Hoodie', 'Jewelry', 'T-shirt',
#        'Scarf', 'Hat', 'Socks', 'Backpack', 'Belt', 'Boots', 'Gloves'],
#       dtype=object)

# %% [markdown]
# # 8.HOW MANY PRODUCTS ARE PURCHASED IN EACH CATEGORY?

# %% [markdown]
# #### This is how to get the number of products purchased based on value_counts

# %%
category_purchased=df['Category'].value_counts()
category_purchased
# Out:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64

# %% [markdown]
# # 9.WHAT IS THE MOST FREQUENTLY PURCHASED ITEM?

# %% [markdown]
# ### this is how we can solve this

# %% [markdown]
# ## alternatively

# %%
df['Item Purchased'].mode()[0]
# this is usually sed whe we have multiple items in the same frequency
# Out:
# 'Blouse'

# %%
# Out:
# Most Frequently Purchased Item:
#  Item Purchased
# Jewelry    4943
# Name: Previous Purchases, dtype: int64

# %% [markdown]
# # 10.WHAT IS THE LIST FREQUENTLY PURCHASED ITEM?

# %%
least_frequent=df['Item Purchased'].value_counts().idxmin()

# %%
least_frequent
# Out:
# 'Jeans'

# %% [markdown]
# # 11 how many unique locations are present in the data

# %% [markdown]
# #### this is how we calculate number of unique location in the data set .unique()

# %%
number_unique _locations=df["Location"].nunique()
# Out:
# 50

# %% [markdown]
# # 12 .WHICH LOCATION HAS HIGHEST NUMBER OF TRANSACTIONS?

# %%
highest_location_trans=df["Location"].mode()[0]
highest_location_trans
# Out:
# 'Montana'

# %% [markdown]
# ### alternatively

# %%
highest_loc_trans=df['Location'].value_counts().idxmax()
highest_loc_trans
# Out:
# 'Montana'

# %% [markdown]
# ### all the above methods are useful in the context of identifying value counts of any items

# %% [markdown]
# # B. DEMOGRAPHIC INSIGHTS ON SHOPPING TRENDS
# ## 1.WHAT IS GENDER DISTRIBUTION OF THE CUSTOMERS ?

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
Gender_data=df["Gender"].value_counts()
Gender_data
# Out:
# Gender
# Male      2652
# Female    1248
# Name: count, dtype: int64

# %% [markdown]
# # 2 . WHAT IS THE AGE RANGE OF THE CUSTOMERS ?

# %%
age_range=df["Age"].max()-df["Age"].min()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
age_range=(df["Age"].min(),df["Age"].max())

# %%
age_range
# Out:
# (18, 70)

# %% [markdown]
# ### the minimum age is 18 and the maximum 70 so the range is 70-18 hence its 52

# %% [markdown]
# # 2.WHAT IS THE AVERAGE AGE OF THE CUSTOMERS MAKING PURCHASES ?

# %%
average=df["Age"].mean()
average
# Out:
# 44.06846153846154

# %% [markdown]
# ### alternatively

# %%
average_age=(df["Age"]/len(df)).sum()
average_age
# Out:
# 44.06846153846154

# %% [markdown]
# # 3. WHICH GENDER SPENDS MORE ON AVERAGE ?

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# #### this methodis not more accurate due since we can have more men than men hence it will not be fair

# %%
more_gender_spend=df.groupby("Gender")["Purchase Amount (USD)"].sum().idxmax()

# %%
more_gender_spend
# Out:
# 'Male'

# %% [markdown]
# ### women spend more based on the data

# %% [markdown]
# ### alternatively

# %%
more_spent_gender=df.groupby('Gender')['Purchase Amount (USD)'].mean()

# %%
more_spent_gender
# Out:
# Gender
# Female    60.249199
# Male      59.536199
# Name: Purchase Amount (USD), dtype: float64

# %% [markdown]
# # 4.WHICH AGE GROUP SPENT THE MOST ?

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
#this creats new column of age group in our data frame
age_group_spent=df.groupby("Age")["Purchase Amount (USD)"].mean().idxmax()
age_group_spent
# Out:
# 53

# %%
df['Age Group'] = pd.cut(df['Age'], bins=[0, 18, 35, 50, 70, 100], labels=['<18', '18-35', '35-50', '50-70', '70+'])

df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
#thia is now grouping based on the column created
age_group_spending = df.groupby('Age Group', observed=False)['Purchase Amount (USD)'].mean()
age_group_spending
# Out:
# Age Group
# <18      59.985507
# 18-35    60.155145
# 35-50    59.072007
# 50-70    59.945799
# 70+            NaN
# Name: Purchase Amount (USD), dtype: float64

# %% [markdown]
# #### this is how to set the customer_id as our new index as there was one which is createa
# df = df.set_index('Customer ID')

# %%
df
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 1             55    Male         Blouse     Clothing                     53
# 2             19    Male        Sweater     Clothing                     64
# 3             50    Male          Jeans     Clothing                     73
# 4             21    Male        Sandals     Footwear                     90
# 5             45    Male         Blouse     Clothing                     49
# ...          ...     ...            ...          ...                    ...
# 3896          40  Female         Hoodie     Clothing                     28
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3899          44  Female          Shoes     Footwear                     77
# 3900          52  Female        Handbag  Accessories                     81
#
# ...

# %%
df
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 1             55    Male         Blouse     Clothing                     53
# 2             19    Male        Sweater     Clothing                     64
# 3             50    Male          Jeans     Clothing                     73
# 4             21    Male        Sandals     Footwear                     90
# 5             45    Male         Blouse     Clothing                     49
# ...          ...     ...            ...          ...                    ...
# 3896          40  Female         Hoodie     Clothing                     28
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3899          44  Female          Shoes     Footwear                     77
# 3900          52  Female        Handbag  Accessories                     81
#
# ...

# %%
df
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 1             55    Male         Blouse     Clothing                     53
# 2             19    Male        Sweater     Clothing                     64
# 3             50    Male          Jeans     Clothing                     73
# 4             21    Male        Sandals     Footwear                     90
# 5             45    Male         Blouse     Clothing                     49
# ...          ...     ...            ...          ...                    ...
# 3896          40  Female         Hoodie     Clothing                     28
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3899          44  Female          Shoes     Footwear                     77
# 3900          52  Female        Handbag  Accessories                     81
#
# ...

# %% [markdown]
# # 5.HOW DOES SPENDING VARY BY GENDER AND CATEGORY ?

# %%
df
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 1             55    Male         Blouse     Clothing                     53
# 2             19    Male        Sweater     Clothing                     64
# 3             50    Male          Jeans     Clothing                     73
# 4             21    Male        Sandals     Footwear                     90
# 5             45    Male         Blouse     Clothing                     49
# ...          ...     ...            ...          ...                    ...
# 3896          40  Female         Hoodie     Clothing                     28
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3899          44  Female          Shoes     Footwear                     77
# 3900          52  Female        Handbag  Accessories                     81
#
# ...

# %%
vary_spend_gend_cat=df.groupby(["Gender","Category"])["Purchase Amount (USD)"].mean()

# %% [markdown]
# vary_spend_gend_cat

# %%
vary_spend_gend_cat=df.aggregate(["Gender","Category"])["Purchase Amount (USD)"].mean()

# %%
vary_spend_gend_cat
# Out:
# Gender  Category
# Female  Accessories    60.762755
#         Clothing       60.496403
#         Footwear       59.472362
#         Outerwear      58.425743
# Male    Accessories    59.411557
#         Clothing       59.803556
#         Footwear       60.645000
#         Outerwear      56.605381
# Name: Purchase Amount (USD), dtype: float64

# %% [markdown]
# # 6.WHAT IS THE CORRELATION BETWEEN AGE AND PURCHASE AMOUNT

# %%
age=df["Age"]
amount_spent=df['Purchase Amount (USD)']

# %% [markdown]
# corre=age.corr(amount_spent)

# %%
corre
# Out:
# -0.010423647378686519

# %% [markdown]
# # C ANALYZING SALES PURFORMANCE BASED ON SHOPPING TRENDS

# %% [markdown]
# # 1.WHAT IS THE TOTAL REVENUE GENERATED FROM THE DATA SET

# %%
df
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 1             55    Male         Blouse     Clothing                     53
# 2             19    Male        Sweater     Clothing                     64
# 3             50    Male          Jeans     Clothing                     73
# 4             21    Male        Sandals     Footwear                     90
# 5             45    Male         Blouse     Clothing                     49
# ...          ...     ...            ...          ...                    ...
# 3896          40  Female         Hoodie     Clothing                     28
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3899          44  Female          Shoes     Footwear                     77
# 3900          52  Female        Handbag  Accessories                     81
#
# ...

# %%
total_rev=df["Purchase Amount (USD)"].sum()

# %%
total_rev
# Out:
# 233081

# %% [markdown]
# # 2. WHAT IS REVENUE DISTRIBUTION ACCROSS CATEGORIES ?

# %%
rev_dist_cat=df.groupby("Category")["Purchase Amount (USD)"].sum()
rev_dist_cat
# Out:
# Category
# Accessories     74200
# Clothing       104264
# Footwear        36093
# Outerwear       18524
# Name: Purchase Amount (USD), dtype: int64

# %% [markdown]
# ### this calculates the amount generated by each category

# %% [markdown]
# # 3.WHICH CATEGORY GENERATES THE MOST REVENUE ?

# %%
most_catt_rev= df.groupby("Category")["Purchase Amount (USD)"].sum().idxmax()

# %%
most_catt_rev
# Out:
# 'Clothing'

# %% [markdown]
# # 4.WHICH CATEGORY GENERATES LEAST REVENUE ?

# %%
leat_rev =df.groupby("Category")["Purchase Amount (USD)"].sum().idxmin()

# %%
leat_rev
# Out:
# 'Outerwear'

# %% [markdown]
# # 4. WHAT IS THE AVERAGE REVENUE PER TRANSACTIONS

# %%
av_rev_transaction=df["Purchase Amount (USD)"].sum()/len(df)

# %%
av_rev_transaction
# Out:
# 59.76435897435898

# %% [markdown]
# ### alternatively

# %%
average_transaction=df["Purchase Amount (USD)"].mean()

# %%
average_transaction
# Out:
# 59.76435897435898

# %% [markdown]
# # 5.WHAT IS THE MEDIAN PURCHASE AMOUNT ACCROSS TRANSACTIONS

# %%
median_transaction=df["Purchase Amount (USD)"].median()
median_transaction
# Out:
# 60.0

# %% [markdown]
# ### the above is how to calculate median

# %% [markdown]
# # 6.WHICH PRODUCTS GENERATE MOST REVENUE ?

# %%
most_gen_product=df.groupby("Item Purchased")["Purchase Amount (USD)"].sum().idxmax()
most_gen_product
# Out:
# 'Blouse'

# %% [markdown]
# # 7.WHICH PRODUCTS GENERATE LEAST  REVENUE ?

# %%
least_gen_product=df.groupby("Item Purchased")["Purchase Amount (USD)"].sum().idxmin()
least_gen_product
# Out:
# 'Jeans'

# %% [markdown]
# # 8.HOW MANY PURCHASES INVOLVES DISCOUNTS

# %%
discout_applied=(df["Discount Applied"]=="Yes").value_counts()
discout_applied
# Out:
# Discount Applied
# False    2223
# True     1677
# Name: count, dtype: int64

# %% [markdown]
# ### this is how to get more distinct sanswers

# %%
discout_applied=(df["Discount Applied"]=="Yes").sum()
discout_applied
# Out:
# 1677

# %% [markdown]
# ### alternatively

# %%
discount_count = df[df['Discount Applied'] == 'Yes'].shape[0]
discount_count
# Out:
# 1677

# %% [markdown]
# #### shape the first value is rows while the second value is columns
